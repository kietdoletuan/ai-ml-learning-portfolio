# %%
from anomalib.data import MVTec
from anomalib.models import Padim
from anomalib.engine import Engine
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from anomalib.data import MVTec
#       2 from anomalib.models import Padim
#       3 from anomalib.engine import Engine
#
# File c:\miniconda3\envs\aio\Lib\site-packages\anomalib\data\__init__.py:15
#      11 from omegaconf import DictConfig, ListConfig
#      13 from anomalib.utils.config import to_tuple
# ---> 15 from .base import AnomalibDataModule, AnomalibDataset
#      16 from .depth import DepthDataFormat, Folder3D, MVTec3D
#      17 from .image import BTech, Datumaro, Folder, ImageDataFormat, Kolektor, MVTec, Visa
#
# File c:\miniconda3\envs\aio\Lib\site-packages\anomalib\data\base\__init__.py:6
#       1 """Base classes for custom dataset and datamodules."""
#       3 # Copyright (C) 2022 Intel Corporation
#       4 # SPDX-License-Identifier: Apache-2.0
# ...

# %%
data_module = MVTec(

)
