# %%
# %matplotlib inline

# %%
from anomalib.data import MVTec
from anomalib.models import Padim
from anomalib.engine import Engine
import matplotlib.pyplot as plt
import numpy as np
import torch

# %%
data_module = MVTec(
    root="data/mvtec_anomaly_detection",
    category="bottle",
    train_batch_size=32,
    eval_batch_size=32,
    num_workers=0
)

model = Padim(
    backbone="resnet18",
    layers=["layer1", "layer2", "layer3"]
)

engine = Engine(
    max_epochs = 1,
    image_metrics=["AUROC"],
    pixel_metrics=["AUROC"],
    accelerator = "auto"
)

# %%
engine.fit(model=model,datamodule=data_module)
results = engine.test(model=model,datamodule=data_module)

print(results)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# `Trainer(val_check_interval=1.0)` was configured so validation will run at the end of the training epoch..
# You are using a CUDA device ('NVIDIA GeForce RTX 3080') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ...

# %%
predictions = engine.predict(model=model, datamodule=data_module)
# Out:
# ckpt_path is not provided. Model weights will not be loaded.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Output()
# c:\miniconda3\envs\aio\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:434: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=31` in the `DataLoader` to improve performance.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
print(type(predictions))
print(type(predictions[0]))
print(predictions[0].keys())
print(predictions[0]['anomaly_maps'].shape)
print(predictions[0]['image'].shape)
# Out:
# <class 'list'>
# <class 'dict'>
# dict_keys(['image_path', 'label', 'image', 'mask', 'anomaly_maps', 'pred_scores', 'pred_labels', 'pred_masks', 'pred_boxes', 'box_scores', 'box_labels'])
# torch.Size([32, 1, 256, 256])
# torch.Size([32, 3, 256, 256])

# %%
mean = torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1)
std  = torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1)

def show_predictions(n=5):
    fig, axes = plt.subplots(3, n, figsize=(15, 3))

    defect_images = []
    defect_maps = []
    defect_masks = []

    for batch in predictions:
        labels = batch['label']
        for i in range(len(labels)):
            if labels[i] == 1:
                defect_images.append(batch['image'][i])
                defect_maps.append(batch['anomaly_maps'][i].squeeze())
                defect_masks.append(batch['mask'][i])
            if len(defect_images) == n:
                break
        if len(defect_images) == n:
            break

    for i in range(n):
        img = defect_images[i] * std + mean
        img = img.permute(1, 2, 0).numpy()
        img = img.clip(0, 1)
        axes[0, i].imshow(img)
        axes[0, i].set_title("Image Input")
        axes[0, i].axis("off")

        axes[1, i].imshow(defect_masks[i])
        axes[1, i].set_title("Masks")
        axes[1, i].axis("off")

        axes[2, i].imshow(defect_maps[i], cmap="hot")
        axes[2, i].set_title("Anomaly Map")
        axes[2, i].axis("off")

    plt.tight_layout()
    plt.show()

# %%
show_predictions(n=5)
# Out:
# C:\Users\kiet0\AppData\Local\Temp\ipykernel_27996\4135889551.py:40: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
import mlflow
import os

categories = ["bottle", "cable", "capsule", "carpet", "grid", "hazelnut",
              "leather", "metal_nut", "pill", "screw", "tile",
              "toothbrush", "transistor", "wood", "zipper"]

results = {}

mlflow.set_experiment("PADIM_MVTEC")
mlflow.set_tracking_uri(f"sqlite:///{os.path.abspath('../../mlflow.db')}")


for cat in categories:
    with mlflow.start_run(run_name=f"padim-{cat}"):
        print(f"==={cat}===")
        data_module = MVTec(
            root="C:/mvtec_ad",
            category=cat,
            train_batch_size=32,
            eval_batch_size=32,
            num_workers=0
        )
        model = Padim()
        engine = Engine(
            default_root_dir="C:/madet_results",
            max_epochs=1,
            image_metrics=["AUROC"],
            pixel_metrics=["AUROC"],
            accelerator="auto"
        )
        engine.fit(model=model, datamodule=data_module)
        test_results = engine.test(model=model, datamodule=data_module)
        results[cat] = test_results[0]
        mlflow.log_metric("image_AUROC", test_results[0]['image_AUROC'])
        mlflow.log_metric("pixel_AUROC", test_results[0]['pixel_AUROC'])
# Out:
# ===bottle===
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# `Trainer(val_check_interval=1.0)` was configured so validation will run at the end of the training epoch..
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\miniconda3\envs\aio\Lib\site-packages\lightning\pytorch\core\optimizer.py:183: `LightningModule.configure_optimizers` returned `None`, this fit will run with no optimizer
# ┏━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name                  ┃ Type                     ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model                 │ PadimModel               │  2.8 M │ train │     0 │
# ...
